# %% [markdown]
#     Q1: Understanding Central Tendency.
#
#     A bakery tracks the daily sales of muffins (in dozens) over a week: [10, 12, 11, 15, 14, 13, 12].
#      What is the most representative value of their weekly sales, and why?
#
# - > Most representative value: 12 dozens (median and mode).
#
# Why?
#
# Mode = 12 dozens (it appears most frequently).
#
# Median = 12 dozens (middle value when data is ordered: 10, 11, 12, 12, 13, 14, 15).
#
# Mean ≈ 12.43 dozens, slightly influenced by higher sales on 14 and 15 days.
#
# Since the data has a small high-value fluctuation, the median/mode (12 dozens) best represents typical weekly muffin sales because it is not affected by extreme values and reflects the most common sales level.
#
#
#
#        Q2: Mean in Real Life
#
#            A teacher records the marks of her students in a short quiz: [12, 15, 14, 16, 18, 20, 19].
#
#            What is the mean score, and what does it tell us about the class’s performance?
#
#   - > Mean score:
# Add all marks and divide by the number of students.
#
# Mean
# =12+15+14+16+18+20+19 / 7 =​
# 114
# 7
# ≈
# 16.29
#
#
# What it tells us:
# The average score of the class is about 16.3 marks.
# This means that, on average, students performed fairly well, with most scores around 16 out of the maximum marks. It gives a general idea of the overall class performance.
#
#      Q3: Mode in Real Life
#      A store records the shoe sizes sold in one day: [7, 8, 9, 8, 8, 10, 7, 9].
#      What is the mode, and why is this information useful for the store manager?
#
# - >  The mode is the value that appears most frequently.
#
# Shoe sizes: [7, 8, 9, 8, 8, 10, 7, 9]
#
# Size 7 → 2 times
#
# Size 8 → 3 times
#
# Size 9 → 2 times
#
# Size 10 → 1 time
#
#   Mode = 8
#
# Why this is useful for the store manager:
# The mode shows the most commonly sold shoe size, so the manager should stock more shoes of size 8. This helps reduce out-of-stock situations and improves sales planning and inventory management.
#
#      Q4: Median in Real Life (Medium)
#       A car dealer notes the prices of used cars: [$8,000, $9,500, $10,200, $11,000, $50,000].
#      Why is the median a better measure than the mean in this case? Calculate the median.
#
# - > There are 5 values, so the median is the middle (3rd) value:
#
#  Median = $10,200
#
#     Why is the median better than the mean here?
#
# The price $50,000 is an extreme value (outlier) compared to the other car prices.
#
# The mean would be pulled up by this very expensive car and would not represent the typical car price.
#
# The median is not affected by extreme values, so it better represents the typical used car price.
#
# Conclusion: The median ($10,200) is a more realistic measure of central value for these car prices.
#
#
#       Q5: Dispersion Introduction
#
#     A student times how long it takes to finish a puzzle each day: [25, 30, 27, 35, 40].
#     What does the range tell us about the variation in the student’s puzzle-solving time?
#
# - >  The range = Maximum value − Minimum value
#
# Puzzle times: [25, 30, 27, 35, 40]
#
# Maximum = 40 minutes
#
# Minimum = 25 minutes
#
# Range
# =
# 40
# −
# 25
# =
# 15
#  minutes
# Range=40−25=15 minutes
#
# What does the range tell us?
#
# The range of 15 minutes shows how much the student’s puzzle-solving time varies from the fastest to the slowest day.
#
#  A larger range means more variation in performance, while a smaller range would mean the student is more consistent.
#
# So, this student’s solving time varies moderately across days.
#
#        Q6: Range in Action
#
#       A farmer records the weekly weight of harvested apples (kg): [100, 105, 98, 110, 120].
#       Find the range. How can this help the farmer in planning his packaging?
#
# - >  The range = Maximum − Minimum
#
# Weekly apple weights: [100, 105, 98, 110, 120]
#
# Maximum = 120 kg
#
# Minimum = 98 kg
#
# Range
# =
# 120
# −
# 98
# =
# 22
#  kg
# Range=120−98=22 kg
#
# How does this help the farmer in planning packaging?
#
# The range of 22 kg shows how much the harvest weight varies from week to week.
#
#   This helps the farmer to:
#
# Prepare extra packaging for high-yield weeks (like 120 kg).
#
# Avoid wasting packaging materials in low-yield weeks (like 98 kg).
#
# Plan storage and transport capacity more efficiently.
#
# Conclusion: The range helps in forecasting variability and planning packaging and logistics.
#
#      Q7: Variance for Decision-Making
#
#      Two delivery companies track delivery delays (in minutes).
#
#       Company A: variance = 6
#
#      Company B: variance = 15
#      Which company is more consistent, and why?
#
# - >
# Company A is more consistent.
#
# Why?
#
# Variance measures how spread out the data is.
#
# A lower variance means the delivery times are more consistent and predictable.
#
# Company A has variance 6, which is smaller than Company B’s variance 15, so its delivery delays vary less.
#
# Conclusion: Company A provides more reliable and stable delivery performance.
#
#      Q8: Standard Deviation in Context
#      A finance student compares the daily price fluctuations of two cryptocurrencies.
#
#      Coin A: standard deviation = $30
#
#       Coin B: standard deviation = $120
#       Which coin is riskier to invest in, and why?
#
# - >  Coin B is riskier to invest in.
#
# Why?
#
# Standard deviation measures how much prices fluctuate around the average price.
#
# A higher standard deviation means greater price volatility, which implies higher uncertainty and risk.
#
# Coin B has a standard deviation of $120,
#
#  which is much larger than Coin A’s $30, so its price changes are more unpredictable.
#
# Conclusion
#
#   Coin B is riskier, but it may also offer higher potential returns.
#   Coin A is more stable and safer for risk-averse investors.
#
#
#
#
#     Q9: Combining Measures
#
#      A family records their monthly electricity usage (in kWh): [400, 420, 390, 450, 410].
#
#        Find the mean and standard deviation. What do these values together tell you about the family’s energy use
#      pattern?
#
# - >  the Mean (Average Electricity Use)
#
# Data: [400, 420, 390, 450, 410]
#
# Mean= 400+420+390+450+410 / 5
# 	​
#
# =
# 2070 /
# 5
# =
# 414
#  kWh
#  Sum of squares = 196 + 36 + 576 + 1296 + 16 = 2120
#
# For population standard deviation:
#
# 𝜎
# =
# 2120
# 5
# =
# 424
# ≈
# 20.6
#  kWh
# σ=
# 5
# 2120
#
#
# =
# 424
# 	​
#
# ≈20.6 kWh
#
# Mean = 414 kWh
#
# Standard Deviation ≈ 20.6 kWh
#
# What do these values tell us about the family’s energy use pattern?
#
# The mean (414 kWh) shows the family’s typical monthly electricity consumption.
#
# The standard deviation (≈ 20.6 kWh) shows moderate variation in their usage.
#
# Interpretation:
#
#   Their electricity use is fairly consistent, with some fluctuations (e.g., higher use in hot/cold months), but no extreme changes.
#
# Conclusion: The family has a stable energy consumption pattern with moderate monthly variation.
#
#
#      Q10: Practical Application
#
#       A basketball player’s points in 8 games are recorded: [15, 18, 20, 22, 25, 17, 19, 21].
#      Find the mean, median, mode, range, and standard deviation. What insights can these measures provide
#      about the player’s scoring performance?
#
# - >
#
# Given data (points in 8 games)
#
# [15, 18, 20, 22, 25, 17, 19, 21]
#
#
#      Mean= 15+18+20+22+25+17+19+21 / 8
# 	​
#
# =
# 157 / 8
#
#  = 19.63
#
#
#       Median
#
# First arrange in order:
#
# [15, 17, 18, 19, 20, 21, 22, 25]
#
# There are 8 values, so median = average of 4th and 5th values:
#
# Median
# =
# 19
# +
# 20 / 2
# =
#    19.5
#
#
#       Mode
#
# No value repeats.
#
#  Mode = None (no most frequent score)
#
#
#      Range
# Range
# =
# 25
# −
# 15
# =
#
#  Range = 10 points
#
#
#       Standard Deviation (Population)
#
# Mean = 19.625
#
#
#
#  Sum of squares ≈ 68.87
#
# 𝜎
# =
# 68.87
# 8
# =
# 8.61
# ≈
# 2.94
# σ=
# 8
# 68
# 	​
#
# ≈2.94
#
#  Standard Deviation ≈ 2.94 points.
#
#
#  Insights About the Player’s Performance
# ✔ Mean & Median
#
# Around 19–20 points per game, so the player is a consistent scorer.
#
# ✔ Mode
#
# No repeated score → performance varies each game.
#
# ✔ Range
#
# Scores vary between 15 and 25 points, so no extreme bad or very high scoring games.
#
# ✔ Standard Deviation
#
# Low SD (~3 points) → scoring is very consistent and stable.
